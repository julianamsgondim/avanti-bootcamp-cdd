# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Conjunto de Dados de Tips

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Dicionário de Dados

# %%
df_dict = pd.DataFrame ( [
   
   {
    "variavel": "sex",
    "descricao": "Gênero ('Female', 'Male')",
    "tipo": "qualitativa",
    "subtipo": "nominal",
   }, {
    "variavel": "day",
    "descricao": "Dia da Semana ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')",
    "tipo": "qualitativa",
    "subtipo": "ordinal",
   }, {
    "variavel": "smoker",
    "descricao": "Fumante? ('Yes', 'No')",
    "tipo": "qualitativa",
    "subtipo": "nominal",
   }, {
    "variavel": "time",
    "descricao": "Horário frequentado",
    "tipo": "qualitativa",
    "subtipo": "nominal",
    }, {
    "variavel": "size",
    "descricao": "Tamanho",
    "tipo": "quantitativa",
    "subtipo": "discreta",
    }, {
    "variavel": "total_bill",
    "descricao": "Total da Gorjeta",
    "tipo": "quantitativa",
    "subtipo": "continua",
    }, {
    "variavel": "tip",
    "descricao": "Total da Gorjeta",
    "tipo": "quantitativa",
    "subtipo": "continua",
    }
       
])

df_dict
# Out:
#      variavel                                          descricao  \
# 0         sex                          Gênero ('Female', 'Male')
# 1         day  Dia da Semana ('Mon', 'Tue', 'Wed', 'Thu', 'Fr...
# 2      smoker                             Fumante? ('Yes', 'No')
# 3        time                                Horário frequentado
# 4        size                                            Tamanho
# 5  total_bill                                   Total da Gorjeta
# 6         tip                                   Total da Gorjeta
#
#            tipo   subtipo
# 0   qualitativa   nominal
# 1   qualitativa   ordinal
# 2   qualitativa   nominal
# 3   qualitativa   nominal
# 4  quantitativa  discreta
# 5  quantitativa  continua
# 6  quantitativa  continua

# %% [markdown]
# ## Estatística Descritiva dos Dados

# %% [markdown]
# ### Variáveis Qualitativas

# %%
df[['sex', 'day', 'smoker', 'time']].mode()
# Out:
#     sex  day smoker    time
# 0  Male  Sat     No  Dinner

# %% [markdown]
# ### Variáveis Quantitativas

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
qualitative_vars = ['sex', 'day', 'smoker', 'time']

for variavel in qualitative_vars: 
    valores_unicos = df[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostra = df[df[variavel] == valor]
        display(subamostra.describe())
        print("="*100)
# Out:
# sex - Female
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000
# ...
# sex - Male
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000
# ...
# day - Sun
#        total_bill        tip       size
# count   76.000000  76.000000  76.000000
# mean    21.410000   3.255132   2.842105
# std      8.832122   1.234880   1.007341
# ...

# %% [markdown]
# # Conjunto de Dados Titanic

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Dicionário de Dados

# %%
df_dict = pd.DataFrame ( [
   
   {
    "variavel": "sex",
    "descricao": "Gênero ('female', 'male')",
    "tipo": "qualitativa",
    "subtipo": "nominal",
   }, {
    "variavel": "age",
    "descricao": "Idade",
    "tipo": "quantitativa",
    "subtipo": "discreta",
   }, {
    "variavel": "fare",
    "descricao": "Tarifa",
    "tipo": "quantitativa",
    "subtipo": "continua",
   }, {
    "variavel": "class",
    "descricao": "Classe",
    "tipo": "qualitativa",
    "subtipo": "ordinal",
    }, {
    "variavel": "embark_town",
    "descricao": "Cidade de Embarque",
    "tipo": "qualitativa",
    "subtipo": "nominal",
    }, {
    "variavel": "alive",
    "descricao": "O passageiro sobreviveu?",
    "tipo": "qualitativa",
    "subtipo": "nominal",
    }, {
    "variavel": "alone",
    "descricao": "O passageiro estava sozinho?",
    "tipo": "qualitativa",
    "subtipo": "nominal",
    }
       
])

df_dict
# Out:
#       variavel                     descricao          tipo   subtipo
# 0          sex     Gênero ('female', 'male')   qualitativa   nominal
# 1          age                         Idade  quantitativa  discreta
# 2         fare                        Tarifa  quantitativa  continua
# 3        class                        Classe   qualitativa   ordinal
# 4  embark_town            Cidade de Embarque   qualitativa   nominal
# 5        alive      O passageiro sobreviveu?   qualitativa   nominal
# 6        alone  O passageiro estava sozinho?   qualitativa   nominal

# %% [markdown]
# ## Estatística Descritiva dos Dados

# %% [markdown]
# ### Variáveis Qualitativas

# %%
df[['sex', 'class', 'embark_town', 'alive', 'alone']].mode()
# Out:
#     sex  class  embark_town alive  alone
# 0  male  Third  Southampton    no   True

# %% [markdown]
# ### Variáveis Quantitativas

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
qualitative_vars = ['sex', 'class', 'embark_town', 'alive', 'alone']

for variavel in qualitative_vars: 
    valores_unicos = df[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostra = df[df[variavel] == valor]
        display(subamostra.describe())
        print("="*100)
# Out:
# sex - male
#          survived      pclass         age       sibsp       parch        fare
# count  577.000000  577.000000  453.000000  577.000000  577.000000  577.000000
# mean     0.188908    2.389948   30.726645    0.429809    0.235702   25.523893
# std      0.391775    0.813580   14.678201    1.061811    0.612294   43.138263
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   21.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   10.500000
# 75%      0.000000    3.000000   39.000000    0.000000    0.000000   26.550000
# max      1.000000    3.000000   80.000000    8.000000    5.000000  512.329200
# ...
# sex - female
#          survived      pclass         age       sibsp       parch        fare
# count  314.000000  314.000000  261.000000  314.000000  314.000000  314.000000
# mean     0.742038    2.159236   27.915709    0.694268    0.649682   44.479818
# ...
